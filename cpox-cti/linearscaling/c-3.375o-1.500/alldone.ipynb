# %%
# this chemkin file is from the cti generated by rmg

# load a bunch of stuff
from __future__ import division
# load
import cantera as ct
import numpy as np
import scipy
import pylab
import matplotlib
import matplotlib.pyplot  as plt
import matplotlib.gridspec as gridspec
from matplotlib.ticker import NullFormatter, MaxNLocator, LogLocator
import csv
from pydas.dassl import DASSL
import os
import rmgpy
import rmg
import re
import operator
import pandas as pd
# %matplotlib inline

gas = ct.Solution('./chem.cti','gas')
surf = ct.Interface('./chem.cti','surface1', [gas])
print "This mechanism contains %d gas reactions and %d surface reactions"%(gas.n_reactions, surf.n_reactions)
i_n2 = gas.species_index('N2')
i_ch4 = gas.species_index('CH4(2)')
i_o2 = gas.species_index('O2(3)')
i_co2 = gas.species_index('CO2(4)')
i_h2o = gas.species_index('H2O(5)')
i_h2 = gas.species_index('H2(6)')
i_co = gas.species_index('CO(7)')
# Out:
# /home/mazeau.e/Code/RMG-Py/rmgpy/tools/plot.py:34: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/tornado/ioloop.py", line 1065, in start
#     handler_func(fd_obj, events)
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-cbe22d16af84>", line 9, in <module>
#     import pylab
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/pylab.py", line 1, in <module>
#     from matplotlib.pylab import *
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/matplotlib/pylab.py", line 252, in <module>
#     from matplotlib import cbook, mlab, pyplot as plt
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/matplotlib/pyplot.py", line 71, in <module>
#     from matplotlib.backends import pylab_setup
#   File "/home/mazeau.e/anaconda2/envs/rmg_env2/lib/python2.7/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   mpl.use('Agg')
# This mechanism contains 737 gas reactions and 233 surface reactions

# %%
#######################################################################
# Input Parameters
#######################################################################

volume = 1.0
cat_area_per_vol = 1.0E2 #I made this up!

cat_area = cat_area_per_vol * volume

#initial conditions
T0 = 1000.
P0 = 1.0 #bar
#initial composition (gas mol fraction)
CH4_0 = 0.1
O2_0 = 0.1
N2_0 = 0.8
CO2_0 = 0.

gas.TPX = T0, P0 * ct.one_atm, {'CH4(2)':CH4_0, 'O2(3)':O2_0, 'N2':N2_0, 'CO2(4)':CO2_0}
          #Temp, Pressure, mole fraction
surf.TP = T0, P0 * ct.one_atm
surf.coverages = {'X(1)':1.0}
#surf.coverages = {'PT(S)':0.9, 'O(S)':0.1}

r = ct.IdealGasConstPressureReactor(gas, energy='off')
r.volume = volume
rsurf = ct.ReactorSurface(surf, r, A=cat_area) # A=cat_area

sim = ct.ReactorNet([r])
sim.max_err_test_fails = 12

# set relative and absolute tolerances on the simulation
sim.rtol = 1.0e-12
sim.atol = 1.0e-18

#rxn_time = np.linspace(1E-12, 5, 10001) #
rxn_time = np.logspace(-4, 3, 10001) #from 0s to 1000s, log spacing

gas_mole_fracs = np.zeros([gas.n_species, len(rxn_time)])
surf_site_fracs = np.zeros([surf.n_species, len(rxn_time)])
temperature = np.zeros(len(rxn_time))    
pressure = np.zeros(len(rxn_time))   

for i in range(len(rxn_time)):
    time = rxn_time[i] #define time in the reactor
    sim.advance(time) #Advance the simulation to next set time
    temperature[i] = gas.T
    pressure[i] = gas.P/ct.one_atm
    gas_mole_fracs[:,i] = gas.X #
    surf_site_fracs[:,i] = surf.coverages #
    if not i % 500:
        print('  {0:10e}  {1:10f}  {2:10f}  {3:10f}'.format(time, *gas['CH4(2)','O2(3)','N2'].X))



#sim.advance_to_steady_state()
#print('  {0:10e}  {1:10f}  {2:10f}  {3:10f}'.format(sim.time, *gas['CH4','H2','CO'].X))    
    
# CH4_ref = gas_mole_fracs[i_ch4,:]

# setting new sensitivity to be based on time to consume 95% of the o2
zipped = zip(gas_mole_fracs[i_o2,:],rxn_time)
zipped = [list(z) for z in zipped]
for z in zipped:
    if z[0] <= O2_0 * .05:
        O2_ref_time = z[1]
        break

#Plot out simulations results
fig = pylab.figure(dpi=300,figsize=(8,8))
gs = gridspec.GridSpec(2, 1)
ax0 = plt.subplot(gs[0])
ax1 = plt.subplot(gs[1])

y_min = 1E-3

for i in range(gas.n_species):
    if i != i_n2:
        if np.max(gas_mole_fracs[i,:]) > y_min:
            ax0.loglog(rxn_time, gas_mole_fracs[i,:], label=gas.species_name(i) )

for i in range(surf.n_species):
    if np.max(surf_site_fracs[i,:]) > y_min:
        ax1.loglog(rxn_time, surf_site_fracs[i,:], label=surf.species_name(i) )
            
ax0.legend(loc='lower left', fontsize = 12)
ax1.legend(loc='lower left', fontsize = 12)

ax0.set_ylabel("gas-phase mole fraction")
ax0.set_ylim(y_min,0.5)
ax0.set_xlim(1.0E-4,max(rxn_time))
ax1.set_xlim(1.0E-4,max(rxn_time))
ax0.set_xlabel("Time(s)")
ax1.set_ylabel("surface site fraction")
#ax0.xaxis.set_major_locator(MaxNLocator(6))
#ax0.yaxis.set_major_locator(LogLocator(base=10.0, numticks=3))
#ax0.tick_params(axis='both', which='major', labelsize=10)
ax1.set_ylim(y_min, 1.1 )
ax1.set_xlabel("Time(s)")


#######################
##   FLUX DIAGRAMS   ##
#######################
steps = len(temperature)
for i in range(0, steps, steps//20):
    gas.TP = temperature[i], pressure[i] * ct.one_atm
    gas.X  = gas_mole_fracs[:,i]
    surf.TP = temperature[i], pressure[i] * ct.one_atm
    surf.coverages = surf_site_fracs[:,i]
    
    element = 'O'

    diagram = ct.ReactionPathDiagram(surf, element)
    diagram.title = 'Reaction path diagram following {0}'.format(element)
    diagram.label_threshold = 0.000001

    dot_file = 'rxnpathO{:06d}.dot'.format(i)
    img_file = 'rxnpathO{:06d}.png'.format(i)
    img_path = os.path.join(os.getcwd(), img_file)

    diagram.write_dot(dot_file)
#     print(diagram.get_data())

    print("Wrote graphviz input file to '{0}'.".format(os.path.join(os.getcwd(), dot_file)))

    os.system('dot {0} -Tpng -o{1} -Gdpi=200'.format(dot_file, img_file))
    print("Wrote graphviz output file to '{0}'.".format(img_path))

    from IPython.display import Image
    Image(filename=img_file) 
    
for i in range(0, steps, steps//20):
    gas.TP = temperature[i], pressure[i] * ct.one_atm
    gas.X  = gas_mole_fracs[:,i]
    surf.TP = temperature[i], pressure[i] * ct.one_atm
    surf.coverages = surf_site_fracs[:,i]
    
    element = 'C'

    diagram = ct.ReactionPathDiagram(surf, element)
    diagram.title = 'Reaction path diagram following {0}'.format(element)
    diagram.label_threshold = 0.000001

    dot_file = 'rxnpathC{:06d}.dot'.format(i)
    img_file = 'rxnpathC{:06d}.png'.format(i)
    img_path = os.path.join(os.getcwd(), img_file)

    diagram.write_dot(dot_file)
#     print(diagram.get_data())

    print("Wrote graphviz input file to '{0}'.".format(os.path.join(os.getcwd(), dot_file)))

    os.system('dot {0} -Tpng -o{1} -Gdpi=200'.format(dot_file, img_file))
    print("Wrote graphviz output file to '{0}'.".format(img_path))

    from IPython.display import Image
    Image(filename=img_file)
# Out:
#   1.000000e-04    0.099996    0.100000    0.800003
#   2.238721e-04    0.099996    0.100000    0.800003
#   5.011872e-04    0.099996    0.100000    0.800003
#   1.122018e-03    0.099996    0.100000    0.800003
#   2.511886e-03    0.099996    0.100000    0.800003
#   5.623413e-03    0.099996    0.099999    0.800003
#   1.258925e-02    0.099994    0.099997    0.800003
#   2.818383e-02    0.099992    0.099991    0.800003
#   6.309573e-02    0.099986    0.099979    0.800003
#   1.412538e-01    0.099971    0.099952    0.800003
#   3.162278e-01    0.099939    0.099891    0.800004
#   7.079458e-01    0.099865    0.099746    0.800004
#   1.584893e+00    0.099689    0.099402    0.800005
#   3.548134e+00    0.099266    0.098571    0.800008
#   7.943282e+00    0.098242    0.096557    0.800017
#   1.778279e+01    0.095649    0.091532    0.800049
#   3.981072e+01    0.032739    0.000000    0.780558
#   8.912509e+01    0.032874    0.000000    0.780317
#   1.995262e+02    0.032958    0.000000    0.780297
#   4.466836e+02    0.033110    0.000000    0.780396
#   1.000000e+03    0.033545    0.000000    0.780561
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO000000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO000000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO000500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO000500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO001000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO001000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO001500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO001500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO002000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO002000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO002500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO002500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO003000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO003000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO003500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO003500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO004000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO004000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO004500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO004500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO005000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO005000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO005500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO005500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO006000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO006000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO006500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO006500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO007000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO007000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO007500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO007500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO008000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO008000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO008500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO008500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO009000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO009000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO009500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO009500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO010000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathO010000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC000000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC000000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC000500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC000500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC001000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC001000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC001500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC001500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC002000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC002000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC002500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC002500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC003000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC003000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC003500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC003500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC004000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC004000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC004500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC004500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC005000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC005000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC005500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC005500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC006000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC006000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC006500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC006500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC007000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC007000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC007500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC007500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC008000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC008000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC008500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC008500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC009000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC009000.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC009500.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC009500.png'.
# Wrote graphviz input file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC010000.dot'.
# Wrote graphviz output file to '/scratch/westgroup/mazeau/surf_w_sensitivity/master/cpox-cti/linearscaling/c-3.375o-1.500/rxnpathC010000.png'.

# %%
with open('time.txt','w') as f:
    f.write(str(O2_ref_time))

# %%
# Set the value of the perturbation
dk = 1.0e-2
# create the array to hold the sensitivty at each time step
Sensitivity = np.zeros([surf.n_reactions,len(rxn_time)])

rxns = []
sens = []

#cycle through each reaction
for m in range(surf.n_reactions):
    surf.set_multiplier(1.0) # reset all multipliers  
    surf.set_multiplier(1+dk, m) # perturb reaction m
    
    gas.TPX = T0, P0 * ct.one_atm, {'CH4(2)':CH4_0, 'O2(3)':O2_0, 'N2':N2_0}
              #Temp, Pressure, mole fraction
    surf.TP = T0, P0 * ct.one_atm
    surf.coverages = {'X(1)':1.0}
    
    r = ct.IdealGasConstPressureReactor(gas, energy='off')
    r.volume = volume
    rsurf = ct.ReactorSurface(surf, r, A=cat_area) # A=cat_area


    sim = ct.ReactorNet([r])
    sim.max_err_test_fails = 12


    # set relative and absolute tolerances on the simulation
    sim.rtol = 1.0e-12
    sim.atol = 1.0e-18
    gas_mole_fracs = np.zeros([gas.n_species, len(rxn_time)])
    temperature = np.zeros(len(rxn_time))    
    pressure = np.zeros(len(rxn_time))   

    for i in range(len(rxn_time)):
        time = rxn_time[i] #define time in the reactor
        sim.advance(time) #Advance the simulation to next set time
        temperature[i] = gas.T
        pressure[i] = gas.P/ct.one_atm
        gas_mole_fracs[:,i] = gas.X #[mol.frac,nth reactor]
    # here is the new output
#     CH4_new = gas_mole_fracs[i_ch4,:]

    O2_new = gas_mole_fracs[i_o2,:]
    zipped = zip(gas_mole_fracs[i_o2,:],rxn_time)
    zipped = [list(z) for z in zipped]
    for z in zipped:
        if z[0] <= O2_0 * .05:
            O2_new_time = z[1]
            break

#     Sens = (CH4_new-CH4_ref)/(CH4_ref*dk)
    Sens = (O2_ref_time - O2_new_time)/(O2_ref_time*dk) # positive if it speeds up the reaction
#     max_sensitivity = max(max(Sens),-min(Sens))
#    if (1==0):
#        if (max_sensitivity>0.01):
#            print "%d %s %.2F"%( m, surf.reaction_equations()[m],  max_sensitivity)
#    else:
#     print "%d %s %.2F"%( m, surf.reaction_equations()[m],  max_sensitivity)
    print "%d %s %.2F"%( m, surf.reaction_equations()[m],  Sens)
#     Sensitivity[m,:] = Sens
    rxns.append(surf.reaction_equations()[m])
    sens.append(Sens)
surf.set_multiplier(1.0)
# Out:
# 0 CH4(2) + X(1) <=> CH4X(45) 0.00
# 1 O2(3) + 2 X(1) <=> 2 OX(20) 0.00
# 2 C2H6(8) + 2 X(1) <=> 2 CH3X(21) 0.00
# 3 CH3(10) + X(1) <=> CH3X(21) -0.48
# 4 CH4(2) + OX(20) + X(1) <=> CH3X(21) + HOX(22) 0.00
# 5 CH3OH(14) + 2 X(1) <=> CH3X(21) + HOX(22) 0.00
# 6 OH(17) + X(1) <=> HOX(22) 0.80
# 7 CH4(2) + HOX(22) + X(1) <=> CH3X(21) + H2OX(23) 0.16
# 8 H2O(5) + X(1) <=> H2OX(23) 0.00
# 9 H2OX(23) + OX(20) <=> 2 HOX(22) -0.32
# 10 H2(6) + 2 X(1) <=> 2 HX(19) 0.00
# 11 HX(19) + OX(20) <=> HOX(22) + X(1) 0.00
# 12 HOX(22) + HX(19) <=> H2OX(23) + X(1) 0.00
# 13 CH3X(21) + HX(19) <=> CH4(2) + 2 X(1) 0.48
# 14 H2O(5) + 2 X(1) <=> HOX(22) + HX(19) -0.16
# 15 H(12) + X(1) <=> HX(19) -0.16
# 16 CH2X(27) + HX(19) <=> CH3X(21) + X(1) -1.62
# 17 CH2X(27) + HOX(22) <=> CH3X(21) + OX(20) -0.16
# 18 CHX(28) + HX(19) <=> CH2X(27) + X(1) 0.00
# 19 CHX(28) + HOX(22) <=> CH2X(27) + OX(20) 0.00
# 20 2 CH2X(27) <=> CH3X(21) + CHX(28) 0.00
# 21 CHX(28) + X(1) <=> CX(26) + HX(19) 0.00
# 22 CX(26) + H2(6) <=> CH2X(27) 0.00
# 23 CX(26) + HOX(22) <=> CHX(28) + OX(20) 0.00
# 24 CH3X(21) + CX(26) <=> CH2X(27) + CHX(28) -0.16
# 25 CH2X(27) + CX(26) <=> 2 CHX(28) 0.00
# 26 CO(7) + X(1) <=> OCX(25) 0.00
# 27 CX(26) + OX(20) <=> OCX(25) + X(1) 0.00
# 28 CO2(4) + X(1) <=> CO2X(24) 0.00
# 29 OCX(25) + OX(20) <=> CO2X(24) + X(1) 0.00
# 30 CO2X(24) + HX(19) <=> HOX(22) + OCX(25) 0.00
# 31 CH3OO(75) + X(1) <=> SX(186) 0.00
# 32 CO(7) + X(1) <=> COX(47) 0.00
# 33 CH3OH(14) + X(1) <=> CH4OX(57) 0.00
# 34 C2H6(8) + X(1) <=> C2H6X(49) 0.00
# 35 H2(6) + X(1) <=> H2X(46) 0.00
# 36 S(197) + 2 X(1) <=> CH3X(21) + SX(186) 0.00
# 37 S(197) + X(1) <=> SX(216) 0.00
# 38 CH2O(9) + X(1) <=> CH2OX(51) 0.00
# 39 HO2X(179) + X(1) <=> HOX(22) + OX(20) 0.00
# 40 HO2(63) + X(1) <=> HO2X(179) 0.00
# 41 CH3OH(14) + 2 X(1) <=> CH3OX(56) + HX(19) 0.00
# 42 CH3OX(56) + X(1) <=> CH2X(27) + HOX(22) 0.00
# 43 CH2X(27) + HO2X(179) <=> CH3OX(56) + OX(20) 0.00
# 44 CH2OX(181) + X(1) <=> CHX(28) + HOX(22) 0.00
# 45 CHX(28) + HO2X(179) <=> CH2OX(181) + OX(20) 0.00
# 46 CH3OX(56) + X(1) <=> CH2OX(181) + HX(19) 0.00
# 47 CH3OX(56) + OX(20) <=> CH2OX(181) + HOX(22) 0.00
# 48 CH2X(27) + CH3OX(56) <=> CH2OX(181) + CH3X(21) 0.00
# 49 CH2OX(181) + CH2X(27) <=> CH3OX(56) + CHX(28) 0.00
# 50 CH3OX(56) + CHX(28) <=> CH2OX(181) + CH2X(27) 0.00
# 51 CH3OX(56) + CX(26) <=> CH2OX(181) + CHX(28) 0.00
# 52 CH2OX(181) + CH2X(27) <=> CH3OX(56) + CHX(28) 0.00
# 53 CH2OX(181) + CH2X(27) <=> CH3OX(56) + CHX(28) 0.00
# 54 CHOX(183) + X(1) <=> CX(26) + HOX(22) 0.00
# 55 CX(26) + HO2X(179) <=> CHOX(183) + OX(20) 0.00
# 56 CH3OX(56) + CX(26) <=> CH2X(27) + CHOX(183) 0.00
# 57 CH2OX(181) + X(1) <=> CHOX(183) + HX(19) 0.00
# 58 CH2OX(181) + OX(20) <=> CHOX(183) + HOX(22) 0.00
# 59 CH2OX(181) + CH2X(27) <=> CH3X(21) + CHOX(183) -0.16
# 60 CH2OX(181) + CHX(28) <=> CH2X(27) + CHOX(183) 0.00
# 61 CHOX(183) + CHX(28) <=> CH2OX(181) + CX(26) 0.00
# 62 CH2OX(181) + CX(26) <=> CHOX(183) + CHX(28) 0.00
# 63 2 CH2OX(181) <=> CH3OX(56) + CHOX(183) 0.00
# 64 CH2OX(181) + CX(26) <=> CHOX(183) + CHX(28) 0.00
# 65 CHOX(183) + CHX(28) <=> CH2OX(181) + CX(26) 0.00
# 66 CH2O(9) + 2 X(1) <=> CHOX(50) + HX(19) -0.48
# 67 HCO(15) + X(1) <=> CHOX(50) 0.00
# 68 CH3CHO(16) + 2 X(1) <=> CH3X(21) + CHOX(50) -0.16
# 69 CH2X(27) + CHOX(50) <=> CH3X(21) + OCX(25) 0.00
# 70 CHOX(50) + OX(20) <=> HOX(22) + OCX(25) 0.00
# 71 CHOX(50) + X(1) <=> HX(19) + OCX(25) 0.00
# 72 CHOX(50) + CHX(28) <=> CH2X(27) + OCX(25) 0.00
# 73 CHOX(50) + CX(26) <=> CHX(28) + OCX(25) 0.00
# 74 CH2OX(181) + CHOX(50) <=> CH3OX(56) + OCX(25) 0.00
# 75 CHOX(183) + CHOX(50) <=> CH2OX(181) + OCX(25) 0.00
# 76 C2H6(8) + 2 X(1) <=> C2H5X(48) + HX(19) 0.00
# 77 C3H8(11) + 2 X(1) <=> C2H5X(48) + CH3X(21) 0.00
# 78 C2H5(13) + X(1) <=> C2H5X(48) 0.00
# 79 C2H5X(48) + X(1) <=> CH2X(27) + CH3X(21) 0.00
# 80 C3H8(11) + X(1) <=> C3H8X(54) 0.00
# 81 C2H5O2(76) + X(1) <=> SX(288) 0.00
# 82 C2H4(18) + X(1) <=> C2H4X(62) 0.00
# 83 C2H6O(121) + 2 X(1) <=> CH3OX(56) + CH3X(21) 0.00
# 84 C2H6O(121) + 2 X(1) <=> C2H5X(48) + HOX(22) 0.00
# 85 C2H6O(121) + X(1) <=> SX(328) 0.00
# 86 CH4O2(187) + 2 X(1) <=> HX(19) + SX(186) 0.00
# 87 CH4O2(187) + 2 X(1) <=> CH3X(21) + HO2X(179) 0.00
# 88 CH4O2(187) + X(1) <=> SX(340) 0.00
# 89 OCO(253) + 2 X(1) <=> CH3OX(56) + HOX(22) -0.16
# 90 OCO(253) + X(1) <=> SX(345) 0.00
# 91 CH3OH(14) + 2 X(1) <=> CH3OX(55) + HX(19) 0.00
# 92 CH3OX(55) + X(1) <=> CH3X(21) + OX(20) 0.00
# 93 SX(186) + X(1) <=> CH3OX(55) + OX(20) 0.00
# 94 S(197) + 2 X(1) <=> 2 CH3OX(55) 0.00
# 95 CH3O(35) + X(1) <=> CH3OX(55) 0.00
# 96 CH2X(27) + CH3OX(55) <=> C2H5X(48) + OX(20) 0.00
# 97 CH4O2(187) + 2 X(1) <=> CH3OX(55) + HOX(22) 0.00
# 98 C2H4(18) + 2 X(1) <=> C2H3X(61) + HX(19) 0.00
# 99 C3H6(354) + 2 X(1) <=> C2H3X(61) + CH3X(21) 0.00
# 100 C3H6(354) + X(1) <=> C3H6X(376) 0.00
# 101 C2H4O(41) + 2 X(1) <=> C2H3X(61) + HOX(22) -0.16
# 102 C2H4O(41) + X(1) <=> SX(451) 0.00
# 103 C3H5X(355) + X(1) <=> C2H3X(61) + CH2X(27) 0.00
# 104 C3H6(354) + 2 X(1) <=> C3H5X(355) + HX(19) 0.00
# 105 X(1) + allyl(368) <=> C3H5X(355) 0.00
# 106 C3H4X(356) + X(1) <=> C2H3X(61) + CHX(28) 0.00
# 107 C3H5X(355) + X(1) <=> C3H4X(356) + HX(19) 0.00
# 108 C3H5X(355) + OX(20) <=> C3H4X(356) + HOX(22) 0.00
# 109 C3H5X(355) + CH2X(27) <=> C3H4X(356) + CH3X(21) 0.00
# 110 C3H4X(356) + CH2X(27) <=> C3H5X(355) + CHX(28) 0.00
# 111 C3H5X(355) + CHX(28) <=> C3H4X(356) + CH2X(27) 0.00
# 112 C3H5X(355) + CX(26) <=> C3H4X(356) + CHX(28) 0.00
# 113 C3H4X(356) + CHOX(50) <=> C3H5X(355) + OCX(25) 0.00
# 114 C3H4X(356) + CH3OX(56) <=> C3H5X(355) + CH2OX(181) 0.00
# 115 C3H4X(356) + CH2OX(181) <=> C3H5X(355) + CHOX(183) 0.00
# 116 C3H4X(356) + CH2X(27) <=> C3H5X(355) + CHX(28) 0.00
# 117 C3H4X(356) + CH2X(27) <=> C3H5X(355) + CHX(28) 0.00
# 118 C3H3X(357) + X(1) <=> C2H3X(61) + CX(26) 0.00
# 119 C3H5X(355) + CX(26) <=> C3H3X(357) + CH2X(27) 0.00
# 120 C3H4X(356) + X(1) <=> C3H3X(357) + HX(19) 0.00
# 121 C3H4X(356) + OX(20) <=> C3H3X(357) + HOX(22) 0.00
# 122 C3H4X(356) + CH2X(27) <=> C3H3X(357) + CH3X(21) 0.00
# 123 C3H4X(356) + CHX(28) <=> C3H3X(357) + CH2X(27) 0.00
# 124 C3H3X(357) + CHX(28) <=> C3H4X(356) + CX(26) 0.00
# 125 C3H4X(356) + CX(26) <=> C3H3X(357) + CHX(28) 0.00
# 126 C3H4X(356) + OCX(25) <=> C3H3X(357) + CHOX(50) 0.00
# 127 C3H4X(356) + CH2OX(181) <=> C3H3X(357) + CH3OX(56) 0.00
# 128 C3H4X(356) + CHOX(183) <=> C3H3X(357) + CH2OX(181) 0.00
# 129 2 C3H4X(356) <=> C3H3X(357) + C3H5X(355) 0.00
# 130 C3H4X(356) + CX(26) <=> C3H3X(357) + CHX(28) 0.00
# 131 C3H3X(357) + CHX(28) <=> C3H4X(356) + CX(26) 0.00
# 132 SX(261) + X(1) <=> CH2OX(181) + CH3X(21) 0.00
# 133 CH2X(27) + SX(261) <=> C2H5X(48) + CH2OX(181) 0.00
# 134 C2H6O(121) + 2 X(1) <=> HX(19) + SX(261) 0.00
# 135 OX(20) + SX(261) <=> CH2OX(181) + CH3OX(55) 0.00
# 136 C2H5O(69) + X(1) <=> SX(261) 0.00
# 137 CH3CHO(16) + X(1) <=> C2H4OX(60) 0.00
# 138 OO(175) + 2 X(1) <=> 2 HOX(22) 0.00
# 139 OO(175) + 2 X(1) <=> HO2X(179) + HX(19) -0.16
# 140 OO(175) + X(1) <=> H2O2X(813) 0.00
# 141 SX(353) + X(1) <=> C2H3X(61) + OX(20) 0.00
# 142 C2H4O(41) + 2 X(1) <=> HX(19) + SX(353) -0.16
# 143 C3H5X(355) + OX(20) <=> CH2X(27) + SX(353) 0.00
# 144 C3H4X(356) + OX(20) <=> CHX(28) + SX(353) 0.00
# 145 CX(26) + SX(353) <=> C3H3X(357) + OX(20) 0.00
# 146 X(1) + vinoxy(38) <=> SX(353) 0.00
# 147 CH3CHO(16) + 2 X(1) <=> C2H3OX(58) + HX(19) 0.00
# 148 C2H3OX(58) + X(1) <=> CH2X(27) + CHOX(50) 0.00
# 149 X(1) + vinoxy(38) <=> C2H3OX(58) -0.16
# 150 SX(274) + X(1) <=> CHOX(50) + CHX(28) 0.00
# 151 C2H3OX(58) + X(1) <=> HX(19) + SX(274) 0.00
# 152 C2H3OX(58) + OX(20) <=> HOX(22) + SX(274) 0.00
# 153 C2H3OX(58) + CH2X(27) <=> CH3X(21) + SX(274) 0.00
# 154 CH2X(27) + SX(274) <=> C2H3OX(58) + CHX(28) 0.00
# 155 C2H3OX(58) + CHX(28) <=> CH2X(27) + SX(274) 0.00
# 156 C2H3OX(58) + CX(26) <=> CHX(28) + SX(274) 0.00
# 157 CHOX(50) + SX(274) <=> C2H3OX(58) + OCX(25) 0.00
# 158 C2H3OX(58) + CH2OX(181) <=> CH3OX(56) + SX(274) 0.00
# 159 C2H3OX(58) + CHOX(183) <=> CH2OX(181) + SX(274) 0.00
# 160 C2H3OX(58) + C3H4X(356) <=> C3H5X(355) + SX(274) 0.00
# 161 C3H4X(356) + SX(274) <=> C2H3OX(58) + C3H3X(357) 0.00
# 162 C2H3OX(58) + CHX(28) <=> CH2X(27) + SX(274) 0.00
# 163 CH2X(27) + SX(274) <=> C2H3OX(58) + CHX(28) 0.00
# 164 C2HOX(275) + X(1) <=> CHOX(50) + CX(26) 0.00
# 165 C2H3OX(58) + CX(26) <=> C2HOX(275) + CH2X(27) 0.00
# 166 SX(274) + X(1) <=> C2HOX(275) + HX(19) 0.00
# 167 OX(20) + SX(274) <=> C2HOX(275) + HOX(22) 0.00
# 168 CH2X(27) + SX(274) <=> C2HOX(275) + CH3X(21) 0.00
# 169 CHX(28) + SX(274) <=> C2HOX(275) + CH2X(27) 0.00
# 170 C2HOX(275) + CHX(28) <=> CX(26) + SX(274) 0.00
# 171 CX(26) + SX(274) <=> C2HOX(275) + CHX(28) 0.00
# 172 OCX(25) + SX(274) <=> C2HOX(275) + CHOX(50) 0.00
# 173 CH2OX(181) + SX(274) <=> C2HOX(275) + CH3OX(56) 0.00
# 174 CHOX(183) + SX(274) <=> C2HOX(275) + CH2OX(181) 0.00
# 175 C3H4X(356) + SX(274) <=> C2HOX(275) + C3H5X(355) 0.00
# 176 C2HOX(275) + C3H4X(356) <=> C3H3X(357) + SX(274) 0.00
# 177 2 SX(274) <=> C2H3OX(58) + C2HOX(275) 0.00
# 178 CX(26) + SX(274) <=> C2HOX(275) + CHX(28) 0.00
# 179 C2HOX(275) + CHX(28) <=> CX(26) + SX(274) 0.00
# 180 CH3CHO(16) + 2 X(1) <=> C2H3OX(59) + HX(19) -0.16
# 181 C2H3OX(59) + X(1) <=> CH3X(21) + OCX(25) 0.00
# 182 C2H3OX(59) + CH2X(27) <=> C2H5X(48) + OCX(25) 0.00
# 183 C2H3OX(59) + OX(20) <=> CH3OX(55) + OCX(25) 0.00
# 184 C2H3OX(59) + CH2OX(181) <=> OCX(25) + SX(261) 0.00
# 185 X(1) + acetyl(39) <=> C2H3OX(59) 0.00
# 186 S(242) + X(1) <=> SX(1224) 0.00
# 187 S(238) + 2 X(1) <=> C2H5X(48) + HO2X(179) 0.00
# 188 S(238) + 2 X(1) <=> HX(19) + SX(288) 0.00
# 189 S(238) + X(1) <=> SX(1307) 0.00
# 190 SX(262) + X(1) <=> CH2OX(181) + HOX(22) 0.00
# 191 CH2OX(181) + HO2X(179) <=> OX(20) + SX(262) 0.00
# 192 CH2X(27) + SX(262) <=> CH2OX(181) + CH3OX(56) 0.00
# 193 CHX(28) + SX(262) <=> 2 CH2OX(181) 0.00
# 194 CX(26) + SX(262) <=> CH2OX(181) + CHOX(183) 0.00
# 195 OCO(253) + 2 X(1) <=> HX(19) + SX(262) 0.00
# 196 CH3O2(344) + X(1) <=> SX(262) 0.00
# 197 CH2O2(85) + 2 X(1) <=> CHOX(50) + HOX(22) 0.00
# 198 CH2O2(85) + X(1) <=> SX(1403) 0.00
# 199 CH2OH(36) + X(1) <=> CH3OX(56) 0.00
# 200 HOCOX(205) + X(1) <=> HOX(22) + OCX(25) 0.00
# 201 HOCOX(205) + OX(20) <=> HO2X(179) + OCX(25) 0.00
# 202 CH2X(27) + HOCOX(205) <=> CH3OX(56) + OCX(25) 0.00
# 203 CHX(28) + HOCOX(205) <=> CH2OX(181) + OCX(25) 0.00
# 204 CX(26) + HOCOX(205) <=> CHOX(183) + OCX(25) 0.00
# 205 CH2OX(181) + HOCOX(205) <=> OCX(25) + SX(262) 0.00
# 206 CH2O2(85) + 2 X(1) <=> HOCOX(205) + HX(19) 0.00
# 207 S(1376) + X(1) <=> SX(1551) 0.00
# 208 S(1357) + 2 X(1) <=> HO2X(179) + SX(262) 0.00
# 209 S(1357) + 2 X(1) <=> HX(19) + SX(1551) 0.00
# 210 S(1357) + X(1) <=> SX(1798) 0.00
# 211 S(1527) + 2 X(1) <=> HOCOX(205) + HOX(22) 0.00
# 212 S(1527) + X(1) <=> SX(1870) 0.00
# 213 S(783) + 2 X(1) <=> HO2X(179) + SX(261) 0.00
# 214 S(783) + 2 X(1) <=> HX(19) + SX(1224) 0.00
# 215 S(783) + X(1) <=> SX(1994) 0.00
# 216 C3H8(11) + 2 X(1) <=> C3H7X(52) + HX(19) 0.00
# 217 C3H7(31) + X(1) <=> C3H7X(52) 0.00
# 218 S(428) + X(1) <=> SX(2139) 0.00
# 219 S(1351) + 2 X(1) <=> HOX(22) + SX(262) 0.00
# 220 S(1351) + X(1) <=> SX(2220) 0.00
# 221 DME(226) + 2 X(1) <=> CH3OX(55) + CH3X(21) 0.00
# 222 DME(226) + X(1) <=> DMEX(2234) 0.00
# 223 CH2X(27) + SX(186) <=> OX(20) + SX(207) 0.00
# 224 SX(207) + X(1) <=> CH2X(27) + CH3OX(55) 0.00
# 225 DME(226) + 2 X(1) <=> HX(19) + SX(207) 0.00
# 226 C2H5O(138) + X(1) <=> SX(207) 0.00
# 227 S(1351) + 2 X(1) <=> HX(19) + SX(2219) 0.00
# 228 S(1817) + X(1) <=> SX(2219) 0.00
# 229 C3H6O(361) + 2 X(1) <=> C2H3X(61) + CH3OX(56) 0.00
# 230 C3H6O(361) + 2 X(1) <=> C3H5X(355) + HOX(22) 0.00
# 231 C3H6O(361) + X(1) <=> SX(2376) 0.00
# 232 HOCO(64) + X(1) <=> HOCOX(205) 0.00

# %%
#Plot out simulations results
# fig = pylab.figure(dpi=300,figsize=(8,8))
# gs = gridspec.GridSpec(1, 1)
# ax0 = plt.subplot(gs[0])


# for m in range(surf.n_reactions):
#     y_max = 0.00001
#     if (1==1):
#         if max(Sensitivity[m,:])>y_max or min(Sensitivity[m,:])<-y_max:
#             lab = surf.reaction_equations()[m]
#             ax0.semilogx(rxn_time, Sensitivity[m,:], label=lab )
#     else:
#         if max(Normed_sensitivity[m,:])>y_max or min(Normed_sensitivity[m,:])<-y_max:
#             lab = surf.reaction_equations()[m]
#             ax0.semilogx(rxn_time, Normed_sensitivity[m,:], label=lab )
        
# ax0.legend(loc='best', fontsize = 12)   
# ax0.set_xlim(rxn_time[1], rxn_time[-1] )

# ax0.set_xlabel("Time(s)")
# ax0.set_ylabel("Sensitivity Coefficient")

# %%
# # now integrate with respect to time
# from numpy import trapz

# # for m in range(surf.n_reactions):
# #     ans = trapz(Sensitivity[m,:], rxn_time)#/max(rxn_time)
# #     if ans>1E-4:
# #         print "%d %s %.5f"%( m, surf.reaction_equations()[m], ans )

# n = []
# rxns = []
# for m in range(surf.n_reactions):
#     n.append(trapz(Sensitivity[m,:], rxn_time))#/max(rxn_time)
#     rxns.append(surf.reaction_equations()[m])

# ans = dict(zip(rxns,n))
# sorted_ans = sorted(ans.items(), key=operator.itemgetter(1), reverse=True)

# for x in sorted_ans:
#     print '%s %.4f'%(x)

# %%
species_dict = rmgpy.data.kinetics.KineticsLibrary().getSpecies('species_dictionary.txt')
keys = species_dict.keys()

# get the first listed smiles string for each molecule
smile = []
for s in species_dict:
    smile.append(species_dict[s].molecule[0])
    if len(species_dict[s].molecule) is not 1:
        print 'There are %d dupllicate smiles for %s:'%(len(species_dict[s].molecule),s)
        for a in range(len(species_dict[s].molecule)):
            print '%s'%(species_dict[s].molecule[a])
            
# translate the molecules from above into just smiles strings
smiles = []
for s in smile:
    smiles.append(s.toSMILES())
    
names = dict(zip(keys,smiles))

rxns_translated = []

# now replace each molecule with smiles
for x in rxns:
    for key, smile in names.iteritems():
        x = re.sub(re.escape(key), smile, x)
    rxns_translated.append(x)

answer = dict(zip(rxns_translated, sens))
sorted_answer = sorted(answer.items(), key=operator.itemgetter(1), reverse=True)
# for x in sorted_answer:
#     print '%s %.4f'%(x)
# Out:
# There are 2 dupllicate smiles for allyl(368):
# <Molecule "[CH2]C=C">
# <Molecule "[CH2]C=C">
# There are 2 dupllicate smiles for vinoxy(38):
# <Molecule "[CH2]C=O">
# <Molecule "C=C[O]">
# There are 2 dupllicate smiles for CHO3(116):
# <Molecule "[O]C(=O)O">
# <Molecule "[O]C(=O)O">

# %%
# write to csv file
(pd.DataFrame.from_dict(data=sorted_answer, orient='columns')
.to_csv('dict.csv', header=False))
